# %%
from keras.datasets import boston_housing
from keras.models import Sequential
from keras.layers import Dense

(X_train, y_train), (X_test, y_test) = boston_housing.load_data()

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(X_train)
Xtr_s = ss.transform(X_train)
Xte_s = ss.transform(X_test)

# %%
model = Sequential()
model.add(Dense(8, activation='relu', input_shape=[X_train.shape[1]]))
model.add(Dense(16, activation='relu'))
model.add(Dense(1))

# %%
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %%
model.fit(Xtr_s, y_train, validation_split=0.2, epochs=10)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 1s 34ms/step - loss: 575.9909 - mae: 21.7408 - val_loss: 618.1661 - val_mae: 22.8828
# Epoch 2/10
# 11/11 [==============================] - 0s 5ms/step - loss: 555.7337 - mae: 21.2261 - val_loss: 604.8177 - val_mae: 22.5519
# Epoch 3/10
# 11/11 [==============================] - 0s 5ms/step - loss: 519.1510 - mae: 20.6475 - val_loss: 591.9227 - val_mae: 22.2325
# Epoch 4/10
# 11/11 [==============================] - 0s 5ms/step - loss: 519.3815 - mae: 20.4050 - val_loss: 579.3504 - val_mae: 21.9353
# Epoch 5/10
# 11/11 [==============================] - 0s 5ms/step - loss: 491.1652 - mae: 20.0349 - val_loss: 566.2901 - val_mae: 21.6241
# Epoch 6/10
# 11/11 [==============================] - 0s 5ms/step - loss: 477.3290 - mae: 19.5215 - val_loss: 552.8443 - val_mae: 21.2876
# Epoch 7/10
# 11/11 [==============================] - 0s 6ms/step - loss: 490.0800 - mae: 19.6135 - val_loss: 540.2252 - val_mae: 20.9630
# Epoch 8/10
# 11/11 [==============================] - 0s 5ms/step - loss: 475.5646 - mae: 19.3025 - val_loss: 526.6697 - val_mae: 20.6078
# Epoch 9/10
# 11/11 [==============================] - 0s 6ms/step - loss: 455.6970 - mae: 18.8258 - val_loss: 512.0392 - val_mae: 20.2217
# Epoch 10/10
# 11/11 [==============================] - 0s 5ms/step - loss: 455.9569 - mae: 18.7507 - val_loss: 498.9778 - val_mae: 19.8790

# %%
mse, mae = model.evaluate(Xte_s, y_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 466.0499 - mae: 19.0654

# %%
print("Mean Average Error: %.2f" % (mae))
# Out:
# Mean Average Error: 19.07
